# %%
import numpy  as np
import pandas as pd
import os
import imageio
import matplotlib.pyplot as plt
import tensorflow

# %%
X_test = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/X_test.npy") # okkey
Y_test = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/Y_test.npy") # okkey

# %%
X_train = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/X_train.npy") # okkey
Y_train = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/Y_train.npy") # okkey

# %%
X_val = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/X_val.npy") # okkey
Y_val = np.load("D:/Ikbal_Hazal_Fatma_Tez/temiz_dataset/Y_val.npy") # okkey

# %% [markdown]
# #### X_rain, X_test and X_val saved for lower bit array  for easy to complete

# %%
X_train.shape
# Out:
# (532, 58, 256, 256, 3)

# %%
X_train.shape


X_train__1 = X_train[0:25,:,:,:,:]
X_train__1.shape

np.save("E:/Temiz dataset/X_train__1",X_train__1)


X_train__2 = X_train[25:50,:,:,:,:]
X_train__2.shape

np.save("E:/Temiz dataset/X_train__2",X_train__2)


X_train__3 = X_train[50:75,:,:,:,:]
X_train__3.shape

np.save("E:/Temiz dataset/X_train__3",X_train__3)



X_train__4 = X_train[75:100,:,:,:,:]
X_train__4.shape

np.save("E:/Temiz dataset/X_train__4",X_train__4)


X_train__5 = X_train[100:125,:,:,:,:]
X_train__5.shape

np.save("E:/Temiz dataset/X_train__5",X_train__5)



X_train__6 = X_train[125:150,:,:,:,:]
X_train__6.shape

np.save("E:/Temiz dataset/X_train__6",X_train__6)



X_train__7 = X_train[150:175,:,:,:,:]
X_train__7.shape

np.save("E:/Temiz dataset/X_train__7",X_train__7)



X_train__8 = X_train[175:200,:,:,:,:]
X_train__8.shape

np.save("E:/Temiz dataset/X_train__8",X_train__8)



X_train__9 = X_train[200:225,:,:,:,:]
X_train__9.shape

np.save("E:/Temiz dataset/X_train__9",X_train__9)



X_train__10 = X_train[225:250,:,:,:,:]
X_train__10.shape

np.save("E:/Temiz dataset/X_train__10",X_train__10)



X_train__11 = X_train[250:275,:,:,:,:]
X_train__11.shape

np.save("E:/Temiz dataset/X_train__11",X_train__11)



X_train__12 = X_train[275:300,:,:,:,:]
X_train__12.shape

np.save("E:/Temiz dataset/X_train__12",X_train__12)


X_train__13 = X_train[300:325,:,:,:,:]
X_train__13.shape

np.save("E:/Temiz dataset/X_train__13",X_train__13)



X_train__14 = X_train[325:350,:,:,:,:]
X_train__14.shape

np.save("E:/Temiz dataset/X_train__14",X_train__14)


X_train__15 = X_train[350:375,:,:,:,:]
X_train__15.shape

np.save("E:/Temiz dataset/X_train__15",X_train__15)



X_train__16 = X_train[375:400,:,:,:,:]
X_train__16.shape

np.save("E:/Temiz dataset/X_train__16",X_train__16)



X_train__17 = X_train[400:425,:,:,:,:]
X_train__17.shape

np.save("E:/Temiz dataset/X_train__17",X_train__17)



X_train__18 = X_train[425:450,:,:,:,:]
X_train__18.shape

np.save("E:/Temiz dataset/X_train__18",X_train__18)



X_train__19 = X_train[450:475,:,:,:,:]
X_train__19.shape

np.save("E:/Temiz dataset/X_train__19",X_train__19)



X_train__20 = X_train[475:500,:,:,:,:]
X_train__20.shape

np.save("E:/Temiz dataset/X_train__20",X_train__20)



X_train__21 = X_train[500:525,:,:,:,:]
X_train__21.shape

np.save("E:/Temiz dataset/X_train__21",X_train__21)



X_train__22 = X_train[525:532,:,:,:,:]
X_train__22.shape

np.save("E:/Temiz dataset/X_train__22",X_train__22)

# %%
X_test.shape
# Out:
# (179, 58, 256, 256, 3)

# %%
X_test.shape


X_test__1 = X_test[0:25,:,:,:,:]
X_test__1.shape

np.save("E:/Temiz dataset/X_test__1",X_test__1)


X_test__2 = X_test[25:50,:,:,:,:]
X_test__2.shape

np.save("E:/Temiz dataset/X_test__2",X_test__2)


X_test__3 = X_test[50:75,:,:,:,:]
X_test__3.shape

np.save("E:/Temiz dataset/X_test__3",X_test__3)



X_test__4 = X_test[75:100,:,:,:,:]
X_test__4.shape

np.save("E:/Temiz dataset/X_test__4",X_test__4)


X_test__5 = X_test[100:125,:,:,:,:]
X_test__5.shape

np.save("E:/Temiz dataset/X_test__5",X_test__5)



X_test__6 = X_test[125:150,:,:,:,:]
X_test__6.shape

np.save("E:/Temiz dataset/X_test__6",X_test__6)



X_test__7 = X_test[150:175,:,:,:,:]
X_test__7.shape

np.save("E:/Temiz dataset/X_test__7",X_test__7)



X_test__8 = X_test[175:179,:,:,:,:]
X_test__8.shape

np.save("E:/Temiz dataset/X_test__8",X_test__8)

# %%
X_val.shape
# Out:
# (140, 58, 256, 256, 3)

# %%
X_val__1 = X_val[0:25,:,:,:,:]
X_val__1.shape

np.save("E:/Temiz dataset/X_val__1",X_val__1)


X_val__2 = X_val[25:50,:,:,:,:]
X_val__2.shape

np.save("E:/Temiz dataset/X_val__2",X_val__2)


X_val__3 = X_val[50:75,:,:,:,:]
X_val__3.shape

np.save("E:/Temiz dataset/X_val__3",X_val__3)



X_val__4 = X_val[75:100,:,:,:,:]
X_val__4.shape

np.save("E:/Temiz dataset/X_val__4",X_val__4)


X_val__5 = X_val[100:125,:,:,:,:]
X_val__5.shape

np.save("E:/Temiz dataset/X_val__5",X_val__5)



X_val__6 = X_val[125:140,:,:,:,:]
X_val__6.shape

np.save("E:/Temiz dataset/X_val__6",X_val__6)

# %% [markdown]
# #### Y_rain, Y_test and Y_val saved for lower bit array  for easy to complete

# %%
Y_train.shape
# Out:
# (532,)

# %%
Y_train__1 = Y_train[0:25]
Y_train__1.shape

np.save("E:/Temiz dataset/Y_train__1",Y_train__1)


Y_train__2 = Y_train[25:50]
Y_train__2.shape

np.save("E:/Temiz dataset/Y_train__2",Y_train__2)


Y_train__3 = Y_train[50:75]
Y_train__3.shape

np.save("E:/Temiz dataset/Y_train__3",Y_train__3)



Y_train__4 = Y_train[75:100]
Y_train__4.shape

np.save("E:/Temiz dataset/Y_train__4",Y_train__4)


Y_train__5 = Y_train[100:125]
Y_train__5.shape

np.save("E:/Temiz dataset/Y_train__5",Y_train__5)



Y_train__6 = Y_train[125:150]
Y_train__6.shape

np.save("E:/Temiz dataset/Y_train__6",Y_train__6)



Y_train__7 = Y_train[150:175]
Y_train__7.shape

np.save("E:/Temiz dataset/Y_train__7",Y_train__7)



Y_train__8 = Y_train[175:200]
Y_train__8.shape

np.save("E:/Temiz dataset/Y_train__8",Y_train__8)



Y_train__9 = Y_train[200:225]
Y_train__9.shape

np.save("E:/Temiz dataset/Y_train__9",Y_train__9)



Y_train__10 = Y_train[225:250]
Y_train__10.shape

np.save("E:/Temiz dataset/Y_train__10",Y_train__10)



Y_train__11 = Y_train[250:275]
Y_train__11.shape

np.save("E:/Temiz dataset/Y_train__11",Y_train__11)



Y_train__12 = Y_train[275:300]
Y_train__12.shape

np.save("E:/Temiz dataset/Y_train__12",Y_train__12)

Y_train__13 = Y_train[300:325]
Y_train__13.shape

np.save("E:/Temiz dataset/Y_train__13",Y_train__13)



Y_train__14 = Y_train[325:350]
Y_train__14.shape

np.save("E:/Temiz dataset/Y_train__14",Y_train__14)


Y_train__15 = Y_train[350:375]
Y_train__15.shape

np.save("E:/Temiz dataset/Y_train__15",Y_train__15)



Y_train__16 = Y_train[375:400]
Y_train__16.shape

np.save("E:/Temiz dataset/Y_train__16",Y_train__16)



Y_train__17 = Y_train[400:425]
Y_train__17.shape

np.save("E:/Temiz dataset/Y_train__17",Y_train__17)



Y_train__18 = Y_train[425:450]
Y_train__18.shape

np.save("E:/Temiz dataset/Y_train__18",Y_train__18)



Y_train__19 = Y_train[450:475]
Y_train__19.shape

np.save("E:/Temiz dataset/Y_train__19",Y_train__19)



Y_train__20 = Y_train[475:500]
Y_train__20.shape

np.save("E:/Temiz dataset/Y_train__20",Y_train__20)



Y_train__21 = Y_train[500:525]
Y_train__21.shape

np.save("E:/Temiz dataset/Y_train__21",Y_train__21)



Y_train__22 = Y_train[525:532]
Y_train__22.shape

np.save("E:/Temiz dataset/Y_train__22",Y_train__22)

# %%
Y_test.shape
# Out:
# (179,)

# %%
Y_test__1 = Y_test[0:25]
Y_test__1.shape

np.save("E:/Temiz dataset/Y_test__1",Y_test__1)


Y_test__2 = Y_test[25:50]
Y_test__2.shape

np.save("E:/Temiz dataset/Y_test__2",Y_test__2)


Y_test__3 = Y_test[50:75]
Y_test__3.shape

np.save("E:/Temiz dataset/Y_test__3",Y_test__3)



Y_test__4 = Y_test[75:100]
Y_test__4.shape

np.save("E:/Temiz dataset/Y_test__4",Y_test__4)


Y_test__5 = Y_test[100:125]
Y_test__5.shape

np.save("E:/Temiz dataset/Y_test__5",Y_test__5)



Y_test__6 = Y_test[125:150]
Y_test__6.shape

np.save("E:/Temiz dataset/Y_test__6",Y_test__6)



Y_test__7 = Y_test[150:175]
Y_test__7.shape

np.save("E:/Temiz dataset/Y_test__7",Y_test__7)



Y_test__8 = Y_test[175:179]
Y_test__8.shape

np.save("E:/Temiz dataset/Y_test__8",Y_test__8)

# %%
Y_val.shape
# Out:
# (140,)

# %%
Y_val__1 = Y_val[0:25]
Y_val__1.shape

np.save("E:/Temiz dataset/Y_val__1",Y_val__1)


Y_val__2 = Y_val[25:50]
Y_val__2.shape

np.save("E:/Temiz dataset/Y_val__2",Y_val__2)


Y_val__3 = Y_val[50:75]
Y_val__3.shape

np.save("E:/Temiz dataset/Y_val__3",Y_val__3)



Y_val__4 = Y_val[75:100]
Y_val__4.shape

np.save("E:/Temiz dataset/Y_val__4",Y_val__4)


Y_val__5 = Y_val[100:125]
Y_val__5.shape

np.save("E:/Temiz dataset/Y_val__5",Y_val__5)



Y_val__6 = Y_val[125:140]
Y_val__6.shape

np.save("E:/Temiz dataset/Y_val__6",Y_val__6)
